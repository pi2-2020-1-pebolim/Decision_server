# %%
import pandas as pd

# %%
import numpy as np

# %%
import glob

# %%
import plotly.graph_objs as go

# %%
lista_arquivos = glob.glob('2020*.txt')

# %%
lista_arquivos
# Out:
# ['20201011_041809.txt',
#  '20201011_041820.txt',
#  '20201011_041832.txt',
#  '20201011_041844.txt',
#  '20201011_041855.txt',
#  '20201011_041907.txt',
#  '20201011_041918.txt',
#  '20201011_041929.txt',
#  '20201011_041941.txt',
#  '20201011_041953.txt',
#  '20201011_042004.txt']

# %%
execution_times = pd.DataFrame(index = [x for x in range(100)])

# %%
for index, arquivo in enumerate(lista_arquivos[:-1]):
    temp = pd.read_table(arquivo, header = None, names = [index])
    execution_times = execution_times.join(temp, how = 'left')

# %%
execution_times = execution_times * 1000

# %%
x_values = [ ]

# %%
y_values = [ ]

# %%
for index, values in execution_times.iteritems():
    x_values.extend([f"Medição {index + 1}"] * 100)
    y_values.extend(values.tolist())

# %%
X_values = [f"Medição {x + 1}" for x in range(11)]

# %%
X_values
# Out:
# ['Medição 1',
#  'Medição 2',
#  'Medição 3',
#  'Medição 4',
#  'Medição 5',
#  'Medição 6',
#  'Medição 7',
#  'Medição 8',
#  'Medição 9',
#  'Medição 10',
#  'Medição 11']

# %%
Y_values = execution_times.mean(axis = 0).values.tolist()

# %%
Y_values
# Out:
# [8.324828147888184,
#  8.85556697845459,
#  9.585514068603516,
#  9.672987461090088,
#  8.166718482971191,
#  8.01135778427124,
#  8.385565280914307,
#  8.450908660888672,
#  9.191820621490479,
#  8.053457736968994]

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x = x_values, y = y_values,
                    mode='markers',
                    name='Tempo'))
fig.add_trace(go.Scatter(x = X_values, y = Y_values,
                    mode='lines+markers',
                    name='Tempo médio'))
fig.show()
# Out:
# <div>
#
#
#             <div id="d1f1b38f-f349-432b-b5c3-c6bba96eee0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d1f1b38f-f349-432b-b5c3-c6bba96eee0e")) {
#                     Plotly.newPlot(
#                         'd1f1b38f-f349-432b-b5c3-c6bba96eee0e',
#                         [{"mode": "markers", "name": "Tempo", "type": "scatter", "x": ["Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 1", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Medi\u00e7\u00e3o 2", "Me ...
